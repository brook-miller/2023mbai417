# %% [markdown]
# <a href="https://colab.research.google.com/github/brook-miller/2023mbai417/blob/main/5-class/synthetic-data-churn-revisited.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this class, we'll be looking at synthetic data generation using the same dataset as the HW3 assignment.  Your job is to assess the synthetically generated data and compare it to the insights you developed in HW3.
#
# Document your findings throughout the exploration.
#
# Description of the dataset variables
# * CLIENTNUM - Client number. Unique identifier for the customer holding the account
# * Attrition_Flag - Internal event (customer activity) variable - if the account is closed then Attrited else Existing
# * Customer_Age - Demographic variable - Customer's Age in Years
# * Gender - Demographic variable - M=Male, F=Female
# * Dependent_count - Demographic variable - Number of dependents
# * Education_Level - Demographic variable - Educational Qualification of the account holder (example: high school, college graduate, etc.)
# * Marital_Status - Demographic variable - Married, Single, Divorced, Unknown
# * Income_Category - Demographic variable - Annual Income Category of the account holder (< $40K , $40K - 60K, $60K - $80K, $ - $120K, > $120K, Unknown)
# * Card_Category - Product Variable - Type of Card (Blue, Silver, Gold, Platinum)
# * Months_on_book - Period of relationship with bank
# * Total_Relationship_Count - Total no. of products held by the customer
# * Months_Inactive_12_mon - No. of months inactive in the last 12 months
# * Contacts_Count_12_mon - o. of Contacts in the last 12 months
# * Credit_Limit - Credit Limit on the Credit Card
# * Total_Revolving_Bal - Total Revolving Balance on the Credit Card
# * Avg_Open_To_Buy - Open to Buy Credit Line (Average of last 12 months)
# * Total_Amt_Chng_Q4_Q1 - Change in Transaction Amount (Q4 over Q1)
# * Total_Trans_Amt - Total Transaction Amount (Last 12 months)
# * Total_Trans_Ct - Total Transaction Count (Last 12 months)
# * Total_Ct_Chng_Q4_Q1 - Change in Transaction Count (Q4 over Q1)
# * Avg_Utilization_Ratio - Average Card Utilization Ratio
#
# Some questions to help you get started:
# * How are Customer demographics (age, gender, ...) distributed?
# * How does the Income category distribution vary based on education level
# * How is Credit limit changing based on gender and marital status
# * What type of cards are people using based on their age groups
# * What could be the cause of attrition (customers dropping off the credit card service)?
#
# In the last cell, assess the data quality.  Does it appear to be accurate?  Are the missing / unknown values especially significant?  Are there clear signals that can be used in downstream model to predict churn?

# %%
#@title Standard imports - we'll use in most EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

from datetime import datetime, timedelta
from dateutil.parser import parse
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/brook-miller/2023mbai417/main/3-homework/bankchurn4.csv')
df
# Out:
# ...
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer             1      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
#!pip install sdv

# %%
df = df.sample(n=500)

from sdv.tabular import CTGAN

model = CTGAN()
model.fit(df)

synthetic_df = model.sample(num_rows=2000)

# %%
synthetic_df
# Out:
# ...
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0     782996988  Attrited Customer            42      M                3
# 1     708112008  Existing Customer            57      F                3
# 2     711820431  Existing Customer            43      M                3
# 3     788759259  Existing Customer            63      F                3
# 4     733813309  Existing Customer            55      M                3
# ...         ...                ...           ...    ...              ...
# 1995  724580528  Existing Customer            48      M                5
# 1996  760264378  Existing Customer            48      M                1
# 1997  755450521  Existing Customer            34      F                5
# 1998  716169845  Existing Customer            48      M                2
# 1999  787628833  Existing Customer            48      M                0
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
#@title repeat some of your EDA tasks from HW3, how does the synthetic data compare?  Is it sensitive to the initial size of the training?
